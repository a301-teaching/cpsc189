# %%
import os,site
currdir=os.getcwd()
head,tail=os.path.split(currdir)
libdir=os.path.join(head,'lib')
site.addsitedir(libdir)
import new_walk
reload(new_walk)
# Out:
# <module 'new_walk' from '/Users/phil/repos/cpsc189/lib/new_walk.pyc'>

# %%
files=new_walk.index('folder_l1_0')

# %%
def tree_to_csv(filename,filelist):
    with open(filename,'w') as f:
        #write the header first
        f.write('file_name;owner;size;modified\n')
        for the_line in filelist:
            f.write("{:s};{:s};{:d};{:d}\n".format(*the_line))
tree_to_csv('out.csv',files)

# %%
import pandas as pd

# %%
data=pd.read_csv('out.csv',sep=';')
data
# Out:
#                                              file_name owner  size  \
# 0                         folder_l1_0/moby_para000.txt  phil  1110
# 1             folder_l1_0/folder_l2_1/moby_para000.txt  phil   762
# 2             folder_l1_0/folder_l2_1/moby_para001.txt  phil   402
# 3    folder_l1_0/folder_l2_1/folder_l3_2/moby_para0...  phil   204
# 4    folder_l1_0/folder_l2_1/folder_l3_2/moby_para0...  phil    85
# 5    folder_l1_0/folder_l2_1/folder_l3_2/moby_para0...  phil   523
# 6    folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil   175
# 7    folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil     0
# 8    folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil    21
# 9    folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil   223
# 10   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil  1906
# 11   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil  2599
# 12   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil  1305
# 13   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil  1366
# 14   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil     0
# 15   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil    27
# 16   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil   868
# 17   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil   886
# 18   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil   255
# 19   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil   170
# 20   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil    45
# 21   folder_l1_0/folder_l2_1/folder_l3_2/folder_l4_...  phil    47
# 22   folder_l1_0/folder_l2_1/folder_l3_1/moby_para0...  phil   233
# 23   folder_l1_0/folder_l2_1/folder_l3_1/moby_para0...  phil   248
# 24   folder_l1_0/folder_l2_1/folder_l3_1/moby_para0...  phil   712
# 25   folder_l1_0/folder_l2_1/folder_l3_1/folder_l4_...  phil    96
# 26   folder_l1_0/folder_l2_1/folder_l3_1/folder_l4_...  phil   333
# 27   folder_l1_0/folder_l2_1/folder_l3_1/folder_l4_...  phil    98
# 28   folder_l1_0/folder_l2_1/folder_l3_1/folder_l4_...  phil   107
# 29   folder_l1_0/folder_l2_1/folder_l3_1/folder_l4_...  phil   300
# ..                                                 ...   ...   ...
# 89   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil  1026
# 90   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil   454
# 91   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil  1065
# 92   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil   344
# 93   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil   197
# 94   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil     0
# 95   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil    27
# 96   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil   313
# 97   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil   542
# 98   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil  1764
# 99   folder_l1_0/folder_l2_0/folder_l3_1/folder_l4_...  phil   309
# 100  folder_l1_0/folder_l2_0/folder_l3_0/moby_para0...  phil   595
# 101  folder_l1_0/folder_l2_0/folder_l3_0/moby_para0...  phil   627
# 102  folder_l1_0/folder_l2_0/folder_l3_0/moby_para0...  phil  1949
# 103  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil    26
# 104  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil   398
# 105  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil  1069
# 106  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil   748
# 107  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil   659
# 108  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil   783
# 109  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil   336
# 110  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil     0
# 111  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil  1183
# 112  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil    67
# 113  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil    31
# 114  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil    32
# 115  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil  1444
# 116  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil   830
# 117  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil   777
# 118  folder_l1_0/folder_l2_0/folder_l3_0/folder_l4_...  phil   708
#
#        modified  level
# 0    1415317570      1
# 1    1415317570      2
# 2    1415317570      2
# 3    1415317570      3
# 4    1415317570      3
# 5    1415317570      3
# 6    1415317570      4
# 7    1415317570      4
# 8    1415317570      4
# 9    1415317570      4
# 10   1415317570      4
# 11   1415317570      4
# 12   1415317570      4
# 13   1415317570      4
# 14   1415317570      4
# 15   1415317570      4
# 16   1415317570      4
# 17   1415317570      4
# 18   1415317570      4
# 19   1415317570      4
# 20   1415317570      4
# 21   1415317570      4
# 22   1415317570      3
# 23   1415317570      3
# 24   1415317570      3
# 25   1415317570      4
# 26   1415317570      4
# 27   1415317570      4
# 28   1415317570      4
# 29   1415317570      4
# ..          ...    ...
# 89   1415317570      4
# 90   1415317570      4
# 91   1415317570      4
# 92   1415317570      4
# 93   1415317570      4
# 94   1415317570      4
# 95   1415317570      4
# 96   1415317570      4
# 97   1415317570      4
# 98   1415317570      4
# 99   1415317570      4
# 100  1415317570      3
# 101  1415317570      3
# 102  1415317570      3
# 103  1415317570      4
# 104  1415317570      4
# 105  1415317570      4
# 106  1415317570      4
# 107  1415317570      4
# 108  1415317570      4
# 109  1415317570      4
# 110  1415317570      4
# 111  1415317570      4
# 112  1415317570      4
# 113  1415317570      4
# 114  1415317570      4
# 115  1415317570      4
# 116  1415317570      4
# 117  1415317570      4
# 118  1415317570      4
#
# [119 rows x 5 columns]
